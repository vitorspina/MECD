# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rng = np.random.uniform(1,52,100)
plt.hist(rng)
# Out:
# (array([10., 11., 16.,  8.,  6., 14., 13.,  5.,  7., 10.]),
#  array([ 1.8217907 ,  6.83520526, 11.84861981, 16.86203437, 21.87544893,
#         26.88886349, 31.90227804, 36.9156926 , 41.92910716, 46.94252172,
#         51.95593627]),
#  <BarContainer object of 10 artists>)
