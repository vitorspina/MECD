# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
numbers = []
for i in range(100000):
    rng = np.random.uniform()
    numbers.append(rng)
plt.hist(numbers)
# Out:
# (array([10000.,  9962.,  9929.,  9985.,  9950.,  9954., 10122., 10071.,
#         10032.,  9995.]),
#  array([1.17564698e-07, 9.99959561e-02, 1.99991795e-01, 2.99987633e-01,
#         3.99983472e-01, 4.99979310e-01, 5.99975149e-01, 6.99970988e-01,
#         7.99966826e-01, 8.99962665e-01, 9.99958503e-01]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
# 15.030689252934554
